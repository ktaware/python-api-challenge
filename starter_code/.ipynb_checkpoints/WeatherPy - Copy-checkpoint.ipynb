# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %% [markdown]
# ##Analysis
# As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %%
cities
# Out:
# ['rikitea',
#  'lorengau',
#  'kalmunai',
#  'punta arenas',
#  'vaini',
#  'gwadar',
#  'hobart',
#  'saint-philippe',
#  'touros',
#  'saleaula',
#  'busselton',
#  'atakpame',
#  'babanusah',
#  'hermanus',
#  'mollendo',
#  'grand river south east',
#  'alvorada',
#  'chuy',
#  'portland',
#  'zuwarah',
#  'lolua',
#  'hilo',
#  'avarua',
#  'vila velha',
#  'husavik',
#  'samusu',
#  'amga',
#  'albany',
#  'puro',
#  'codrington',
#  'grindavik',
#  'bluff',
#  'nikolskoye',
#  'namatanai',
#  'dzhusaly',
#  'sistranda',
#  'port alfred',
#  'markova',
#  'aden',
#  'east london',
#  'sisimiut',
#  'seoul',
#  'luderitz',
#  'qaanaaq',
#  'souillac',
#  'shubarshi',
#  'butaritari',
#  'atuona',
#  'bredasdorp',
#  'tsihombe',
#  'illoqqortoormiut',
#  'castro',
#  'cape town',
#  'jamestown',
#  'kutahya',
#  'matsanga',
#  'kapaa',
#  'umm lajj',
#  'clyde river',
#  'port blair',
#  'karratha',
#  'sabzevar',
#  'roald',
#  'sorong',
#  'timra',
#  'los llanos de aridane',
#  'taolanaro',
#  'sumbawa',
#  'payson',
#  'ilulissat',
#  'mataura',
#  'phan thiet',
#  'lunavada',
#  'spoleto',
#  'hasaki',
#  'barentsburg',
#  'belushya guba',
#  'villa carlos paz',
#  'lebu',
#  'dikson',
#  'ushuaia',
#  'faanui',
#  'kjollefjord',
#  'lanja',
#  'manokwari',
#  'narsaq',
#  'birin',
#  'obidos',
#  'lisakovsk',
#  'komsomolskiy',
#  'mayumba',
#  'suffolk',
#  'ambon',
#  'one hundred mile house',
#  'georgetown',
#  'darnah',
#  'te anau',
#  'leningradskiy',
#  'fort wellington',
#  'shangrao',
#  'hualmay',
#  'inongo',
#  'usvyaty',
#  'upernavik',
#  'srednekolymsk',
#  'mar del plata',
#  'mitsamiouli',
#  'shimoda',
#  'puerto ayora',
#  'barsovo',
#  'san juan pueblo',
#  'hervey bay',
#  'tahara',
#  'bengkulu',
#  'new norfolk',
#  'shaoguan',
#  'yellowknife',
#  'benidorm',
#  'neuquen',
#  'isangel',
#  'berlevag',
#  'attawapiskat',
#  'barrow',
#  'arraial do cabo',
#  'andenes',
#  'grand gaube',
#  'tasiilaq',
#  'fare',
#  'ileza',
#  'mulatupo',
#  'longyearbyen',
#  'bathsheba',
#  'kazalinsk',
#  'saint-augustin',
#  'kamenskoye',
#  'alghero',
#  'atar',
#  'fortuna',
#  'tuatapere',
#  'guane',
#  'saskylakh',
#  'bonavista',
#  'aklavik',
#  'kuche',
#  'sentyabrskiy',
#  'visnes',
#  'constitucion',
#  'kaitangata',
#  'magadan',
#  'brae',
#  'myatlevo',
#  'lagoa',
#  'samarai',
#  'anadyr',
#  'mogadishu',
#  'kijang',
#  'sitka',
#  'carnarvon',
#  'nalut',
#  'thompson',
#  'klaksvik',
#  'hithadhoo',
#  'prince rupert',
#  'yulara',
#  'macau',
#  'vao',
#  'weligama',
#  'nador',
#  'port hedland',
#  'ornskoldsvik',
#  'elizabeth city',
#  'ambikapur',
#  'beringovskiy',
#  'cabo san lucas',
#  'iraquara',
#  'san carlos de bariloche',
#  'cherskiy',
#  'sao jose da coroa grande',
#  'zomba',
#  'khatanga',
#  'strezhevoy',
#  'adrar',
#  'dongfeng',
#  'sur',
#  'alta floresta',
#  'asau',
#  'diego de almagro',
#  'gigmoto',
#  'tuktoyaktuk',
#  'umm ruwabah',
#  'tavai',
#  'ahuimanu',
#  'bethel',
#  'pingliang',
#  'nagda',
#  'mys shmidta',
#  'rio gallegos',
#  'port elizabeth',
#  'arlit',
#  'kruisfontein',
#  'rabaul',
#  'ponta do sol',
#  'iralaya',
#  'abha',
#  'troitsko-pechorsk',
#  'brigantine',
#  'seredka',
#  'nemuro',
#  'huittinen',
#  'praia',
#  'mutare',
#  'port macquarie',
#  'lubao',
#  'harper',
#  'san quintin',
#  'ullapool',
#  'merauke',
#  'esna',
#  'bambous virieux',
#  'natal',
#  'oranjemund',
#  'soltsy',
#  'rudnogorsk',
#  'paraguacu paulista',
#  'erenhot',
#  'maniitsoq',
#  'ribeira grande',
#  'victoria',
#  'rameshki',
#  'san vicente',
#  'mahibadhoo',
#  'san jose',
#  'glendive',
#  'wenatchee',
#  'polyarnyy',
#  'xining',
#  'colombo',
#  'nouadhibou',
#  'quatre cocos',
#  'torbay',
#  'sampit',
#  'marovoay',
#  'yarada',
#  'paamiut',
#  'ust-kut',
#  'olafsvik',
#  'uruzgan',
#  'sao felix do xingu',
#  'prainha',
#  'nogliki',
#  'honggang',
#  'tommot',
#  'port lincoln',
#  'maua',
#  'comodoro rivadavia',
#  'kameno',
#  'marsaxlokk',
#  'hovd',
#  'amberley',
#  'tenosique',
#  'jaramana',
#  'shenjiamen',
#  'steinbach',
#  'camopi',
#  'erzin',
#  'pochutla',
#  'mount gambier',
#  'nuuk',
#  'alice springs',
#  'madera',
#  'aksu',
#  'alexandria',
#  'bubaque',
#  'meadville',
#  'nantucket',
#  'samalaeulu',
#  'garissa',
#  'marcona',
#  'ordubad',
#  'temaraia',
#  'axim',
#  'ipixuna',
#  'sakakah',
#  'chardara',
#  'idlib',
#  'kodiak',
#  'belyy yar',
#  'vaitupu',
#  'nizwa',
#  'aksha',
#  'guerrero negro',
#  'iqaluit',
#  'pozhva',
#  'stokmarknes',
#  'matay',
#  'chore',
#  'guiong',
#  'davila',
#  'neufchateau',
#  'ugoofaaru',
#  'mataram',
#  'porto novo',
#  'geraldton',
#  'tawzar',
#  'aitape',
#  'san patricio',
#  'sinazongwe',
#  'auki',
#  'anchorage',
#  'parrita',
#  'kavieng',
#  'poya',
#  'cairns',
#  'xiongyue',
#  'mikuni',
#  'airai',
#  'colares',
#  'nokaneng',
#  'malartic',
#  'borba',
#  'cabinda',
#  'honiara',
#  'nanortalik',
#  'langres',
#  'ozinki',
#  'chake chake',
#  'iba',
#  'watertown',
#  'chapais',
#  'yuci',
#  'kirakira',
#  'kaniama',
#  'saint george',
#  'storforshei',
#  'dingle',
#  'santiago de chuco',
#  'timmins',
#  'uvat',
#  'teberda',
#  'deputatskiy',
#  'manzhouli',
#  'nizhneyansk',
#  'zaysan',
#  'san ramon de la nueva oran',
#  'mandalgovi',
#  'kabalo',
#  'afonso bezerra',
#  'heiligenhafen',
#  'iquitos',
#  'awbari',
#  'timbiqui',
#  'inirida',
#  'yamethin',
#  'lephepe',
#  'mahebourg',
#  'urtaaul',
#  'stuttgart',
#  'carlsbad',
#  'vardo',
#  'axixa do tocantins',
#  'vila',
#  'pevek',
#  'katikati',
#  'kendari',
#  'igarka',
#  'luanda',
#  'sao filipe',
#  'dwarka',
#  'polunochnoye',
#  'vesyegonsk',
#  'tessalit',
#  'meyungs',
#  'uyuni',
#  'coffs harbour',
#  'padang',
#  'taoudenni',
#  'flinders',
#  'ratanpur',
#  'saint-pierre',
#  'saravan',
#  'yatou',
#  'aljezur',
#  'meulaboh',
#  'ust-tsilma',
#  'yeppoon',
#  'fengrun',
#  'bargal',
#  'cabo rojo',
#  'mackay',
#  'henties bay',
#  'plettenberg bay',
#  'ostrovnoy',
#  'fort nelson',
#  'ushtobe',
#  'longlac',
#  'macaboboni',
#  'belozerskoye',
#  'uyskoye',
#  'gat',
#  'okha',
#  'namibe',
#  'harpalpur',
#  'tiksi',
#  'yarmouth',
#  'belmonte',
#  'lasa',
#  'kidal',
#  'makakilo city',
#  'talnakh',
#  'gizo',
#  'qaqortoq',
#  'shakhtinsk',
#  'emerald',
#  'bac can',
#  'margate',
#  'port hawkesbury',
#  'barabash',
#  'barillas',
#  'bria',
#  'amderma',
#  'camacha',
#  'dire dawa',
#  'chifeng',
#  'tabiauea',
#  'tutin',
#  'matamoros',
#  'moba',
#  'katsuura',
#  'el dorado',
#  'goundam',
#  'ahipara',
#  'necochea',
#  'mizpe ramon',
#  'chokurdakh',
#  'matara',
#  'peterhead',
#  'lerwick',
#  'pangnirtung',
#  'kahului',
#  'pokrovka',
#  'turayf',
#  'coquimbo',
#  'haines junction',
#  'ndjole',
#  'pisco',
#  'batagay',
#  'ponta delgada',
#  'itarema',
#  'richards bay',
#  'umzimvubu',
#  'boyolangu',
#  'khani',
#  'kisangani',
#  'garowe',
#  'iranshahr',
#  'vedaranniyam',
#  'hailar',
#  'rezina',
#  'egvekinot',
#  'eureka',
#  'bastrop',
#  'ilirska bistrica',
#  'tongliao',
#  'saurimo',
#  'digha',
#  'ancud',
#  'juba',
#  'rungata',
#  'chengdu',
#  'wladyslawowo',
#  'poum',
#  'severo-kurilsk',
#  'coihaique',
#  'akyab',
#  'acapulco',
#  'tara',
#  'kropotkin',
#  'mufulira',
#  'provideniya',
#  'hay river',
#  'miro khan',
#  'suoyarvi',
#  'valley city',
#  'muros',
#  'ha giang',
#  'salta',
#  'armidale',
#  'saldanha',
#  'corrente',
#  'tapaua',
#  'oyama',
#  'caarapo',
#  'stykkisholmur',
#  'cayenne',
#  'cidreira',
#  'tomatlan',
#  'ust-kuyga',
#  'kavaratti',
#  'barra',
#  'iwanai',
#  'zyryanka',
#  'redcliffe',
#  'mlowo',
#  'a coruna',
#  'puerto escondido',
#  'gushikawa',
#  'maryborough',
#  'bilma',
#  'marquard',
#  'kumeny',
#  'broome',
#  'progreso',
#  'sechura',
#  'marawi',
#  'tanout',
#  'chinsali',
#  'puerto ayacucho',
#  'bara',
#  'carutapera',
#  'kayerkan',
#  'rio verde de mato grosso',
#  'shahi',
#  'waddan',
#  'novyy urgal',
#  'sobolevo',
#  'chagda',
#  'wiang sa',
#  'norman wells',
#  'labutta',
#  'lompoc',
#  'kota bahru',
#  'gorontalo',
#  'cap malheureux',
#  'sept-iles',
#  'tarakan',
#  'burica',
#  'kazerun',
#  'ranfurly',
#  'aykhal',
#  'anito',
#  'vanavara',
#  'devils lake',
#  'berberati',
#  'san borja',
#  'staryy nadym',
#  'stilfontein',
#  'dujuma',
#  'catuday',
#  'namsos',
#  'fershampenuaz',
#  'diffa',
#  'kudahuvadhoo',
#  'nguiu',
#  'atikokan',
#  'rawson',
#  'miri',
#  'tucuma',
#  'yining',
#  'haibowan',
#  'shawinigan',
#  'bandarbeyla',
#  'sola',
#  'saint-georges',
#  'houma',
#  'tyup',
#  'rondonopolis',
#  'tocopilla',
#  'kohtla-jarve',
#  'warmbad',
#  'methoni',
#  'tura',
#  'levin',
#  'dalnegorsk',
#  'bomi',
#  'torbat-e jam',
#  'lumphat',
#  'morant bay',
#  'ahtopol',
#  'shingu',
#  'sao miguel do araguaia',
#  'esperance',
#  'calamar',
#  'yeletskiy',
#  'jizan',
#  'conceicao do araguaia',
#  'horasan',
#  'gloversville',
#  'simplicio mendes',
#  'wahran',
#  'salamiyah',
#  'khomeyn',
#  'saint anthony',
#  'flin flon',
#  'segou',
#  'port hardy',
#  'san cristobal',
#  'oktyabrskoye',
#  'makokou',
#  'oriximina',
#  'carballo',
#  'bolungarvik',
#  'winneba',
#  'huarmey',
#  'teya',
#  'montepuez',
#  'tarko-sale',
#  'xuanhua',
#  'tabou',
#  'katherine']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
   
    
    
    try: 
        r = requests.get( city_url)
        r.status_code
        city_info = r.json()
 
        #Parse the JSON and retrieve data
        city_weather =  city_info["weather"]
                
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_info ["coord"]['lat']
        city_lng = city_info["coord"]['lon'] 
        city_max_temp =  city_info['main']['temp_max']
        city_humidity =  city_info['main']['humidity']
        city_clouds = city_info ['clouds']['all']
        city_wind = city_info[ 'wind'] ["speed"]
        city_country = city_info['sys']['country'] 
        city_date =  city_info['dt']

         # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass



# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | lorengau
# Processing Record 3 of Set 1 | kalmunai
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | gwadar
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | touros
# Processing Record 10 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | atakpame
# Processing Record 13 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | mollendo
# Processing Record 16 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 1 | alvorada
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | portland
# Processing Record 20 of Set 1 | zuwarah
# Processing Record 21 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | vila velha
# Processing Record 25 of Set 1 | husavik
# Processing Record 26 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 1 | amga
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | puro
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | grindavik
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | namatanai
# Processing Record 35 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 1 | sistranda
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | markova
# Processing Record 39 of Set 1 | aden
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | sisimiut
# Processing Record 42 of Set 1 | seoul
# Processing Record 43 of Set 1 | luderitz
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | shubarshi
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | kutahya
# Processing Record 5 of Set 2 | matsanga
# City not found. Skipping...
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | umm lajj
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | port blair
# Processing Record 10 of Set 2 | karratha
# Processing Record 11 of Set 2 | sabzevar
# Processing Record 12 of Set 2 | roald
# Processing Record 13 of Set 2 | sorong
# Processing Record 14 of Set 2 | timra
# Processing Record 15 of Set 2 | los llanos de aridane
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 2 | payson
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | phan thiet
# Processing Record 22 of Set 2 | lunavada
# Processing Record 23 of Set 2 | spoleto
# Processing Record 24 of Set 2 | hasaki
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | villa carlos paz
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | faanui
# Processing Record 32 of Set 2 | kjollefjord
# Processing Record 33 of Set 2 | lanja
# Processing Record 34 of Set 2 | manokwari
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | birin
# Processing Record 37 of Set 2 | obidos
# Processing Record 38 of Set 2 | lisakovsk
# Processing Record 39 of Set 2 | komsomolskiy
# Processing Record 40 of Set 2 | mayumba
# Processing Record 41 of Set 2 | suffolk
# Processing Record 42 of Set 2 | ambon
# Processing Record 43 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | darnah
# Processing Record 46 of Set 2 | te anau
# Processing Record 47 of Set 2 | leningradskiy
# Processing Record 48 of Set 2 | fort wellington
# Processing Record 49 of Set 2 | shangrao
# Processing Record 0 of Set 3 | hualmay
# Processing Record 1 of Set 3 | inongo
# Processing Record 2 of Set 3 | usvyaty
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | srednekolymsk
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | mitsamiouli
# Processing Record 7 of Set 3 | shimoda
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | barsovo
# Processing Record 10 of Set 3 | san juan pueblo
# Processing Record 11 of Set 3 | hervey bay
# Processing Record 12 of Set 3 | tahara
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | new norfolk
# Processing Record 15 of Set 3 | shaoguan
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | benidorm
# Processing Record 18 of Set 3 | neuquen
# Processing Record 19 of Set 3 | isangel
# Processing Record 20 of Set 3 | berlevag
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | andenes
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | fare
# Processing Record 28 of Set 3 | ileza
# Processing Record 29 of Set 3 | mulatupo
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | bathsheba
# Processing Record 32 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 3 | saint-augustin
# Processing Record 34 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 3 | alghero
# Processing Record 36 of Set 3 | atar
# Processing Record 37 of Set 3 | fortuna
# Processing Record 38 of Set 3 | tuatapere
# Processing Record 39 of Set 3 | guane
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | bonavista
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | visnes
# Processing Record 46 of Set 3 | constitucion
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | magadan
# Processing Record 49 of Set 3 | brae
# Processing Record 0 of Set 4 | myatlevo
# Processing Record 1 of Set 4 | lagoa
# Processing Record 2 of Set 4 | samarai
# Processing Record 3 of Set 4 | anadyr
# Processing Record 4 of Set 4 | mogadishu
# Processing Record 5 of Set 4 | kijang
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | nalut
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | klaksvik
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | prince rupert
# Processing Record 13 of Set 4 | yulara
# Processing Record 14 of Set 4 | macau
# Processing Record 15 of Set 4 | vao
# Processing Record 16 of Set 4 | weligama
# Processing Record 17 of Set 4 | nador
# Processing Record 18 of Set 4 | port hedland
# Processing Record 19 of Set 4 | ornskoldsvik
# Processing Record 20 of Set 4 | elizabeth city
# Processing Record 21 of Set 4 | ambikapur
# Processing Record 22 of Set 4 | beringovskiy
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | iraquara
# Processing Record 25 of Set 4 | san carlos de bariloche
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | sao jose da coroa grande
# Processing Record 28 of Set 4 | zomba
# Processing Record 29 of Set 4 | khatanga
# Processing Record 30 of Set 4 | strezhevoy
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | dongfeng
# Processing Record 33 of Set 4 | sur
# Processing Record 34 of Set 4 | alta floresta
# Processing Record 35 of Set 4 | asau
# Processing Record 36 of Set 4 | diego de almagro
# Processing Record 37 of Set 4 | gigmoto
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 40 of Set 4 | tavai
# City not found. Skipping...
# Processing Record 41 of Set 4 | ahuimanu
# Processing Record 42 of Set 4 | bethel
# Processing Record 43 of Set 4 | pingliang
# Processing Record 44 of Set 4 | nagda
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | rio gallegos
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | arlit
# Processing Record 49 of Set 4 | kruisfontein
# Processing Record 0 of Set 5 | rabaul
# Processing Record 1 of Set 5 | ponta do sol
# Processing Record 2 of Set 5 | iralaya
# Processing Record 3 of Set 5 | abha
# Processing Record 4 of Set 5 | troitsko-pechorsk
# Processing Record 5 of Set 5 | brigantine
# Processing Record 6 of Set 5 | seredka
# Processing Record 7 of Set 5 | nemuro
# Processing Record 8 of Set 5 | huittinen
# Processing Record 9 of Set 5 | praia
# Processing Record 10 of Set 5 | mutare
# Processing Record 11 of Set 5 | port macquarie
# Processing Record 12 of Set 5 | lubao
# Processing Record 13 of Set 5 | harper
# Processing Record 14 of Set 5 | san quintin
# Processing Record 15 of Set 5 | ullapool
# Processing Record 16 of Set 5 | merauke
# Processing Record 17 of Set 5 | esna
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | natal
# Processing Record 20 of Set 5 | oranjemund
# Processing Record 21 of Set 5 | soltsy
# Processing Record 22 of Set 5 | rudnogorsk
# Processing Record 23 of Set 5 | paraguacu paulista
# Processing Record 24 of Set 5 | erenhot
# Processing Record 25 of Set 5 | maniitsoq
# Processing Record 26 of Set 5 | ribeira grande
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | rameshki
# Processing Record 29 of Set 5 | san vicente
# Processing Record 30 of Set 5 | mahibadhoo
# Processing Record 31 of Set 5 | san jose
# Processing Record 32 of Set 5 | glendive
# Processing Record 33 of Set 5 | wenatchee
# Processing Record 34 of Set 5 | polyarnyy
# Processing Record 35 of Set 5 | xining
# Processing Record 36 of Set 5 | colombo
# Processing Record 37 of Set 5 | nouadhibou
# Processing Record 38 of Set 5 | quatre cocos
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | sampit
# Processing Record 41 of Set 5 | marovoay
# Processing Record 42 of Set 5 | yarada
# Processing Record 43 of Set 5 | paamiut
# Processing Record 44 of Set 5 | ust-kut
# Processing Record 45 of Set 5 | olafsvik
# Processing Record 46 of Set 5 | uruzgan
# Processing Record 47 of Set 5 | sao felix do xingu
# Processing Record 48 of Set 5 | prainha
# Processing Record 49 of Set 5 | nogliki
# Processing Record 0 of Set 6 | honggang
# Processing Record 1 of Set 6 | tommot
# Processing Record 2 of Set 6 | port lincoln
# Processing Record 3 of Set 6 | maua
# Processing Record 4 of Set 6 | comodoro rivadavia
# Processing Record 5 of Set 6 | kameno
# Processing Record 6 of Set 6 | marsaxlokk
# Processing Record 7 of Set 6 | hovd
# Processing Record 8 of Set 6 | amberley
# Processing Record 9 of Set 6 | tenosique
# Processing Record 10 of Set 6 | jaramana
# City not found. Skipping...
# Processing Record 11 of Set 6 | shenjiamen
# Processing Record 12 of Set 6 | steinbach
# Processing Record 13 of Set 6 | camopi
# Processing Record 14 of Set 6 | erzin
# Processing Record 15 of Set 6 | pochutla
# Processing Record 16 of Set 6 | mount gambier
# Processing Record 17 of Set 6 | nuuk
# Processing Record 18 of Set 6 | alice springs
# Processing Record 19 of Set 6 | madera
# Processing Record 20 of Set 6 | aksu
# Processing Record 21 of Set 6 | alexandria
# Processing Record 22 of Set 6 | bubaque
# Processing Record 23 of Set 6 | meadville
# Processing Record 24 of Set 6 | nantucket
# Processing Record 25 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 6 | garissa
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | ordubad
# Processing Record 29 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 6 | axim
# Processing Record 31 of Set 6 | ipixuna
# Processing Record 32 of Set 6 | sakakah
# Processing Record 33 of Set 6 | chardara
# Processing Record 34 of Set 6 | idlib
# Processing Record 35 of Set 6 | kodiak
# Processing Record 36 of Set 6 | belyy yar
# Processing Record 37 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 6 | nizwa
# Processing Record 39 of Set 6 | aksha
# Processing Record 40 of Set 6 | guerrero negro
# Processing Record 41 of Set 6 | iqaluit
# Processing Record 42 of Set 6 | pozhva
# Processing Record 43 of Set 6 | stokmarknes
# Processing Record 44 of Set 6 | matay
# Processing Record 45 of Set 6 | chore
# City not found. Skipping...
# Processing Record 46 of Set 6 | guiong
# Processing Record 47 of Set 6 | davila
# Processing Record 48 of Set 6 | neufchateau
# Processing Record 49 of Set 6 | ugoofaaru
# Processing Record 0 of Set 7 | mataram
# Processing Record 1 of Set 7 | porto novo
# Processing Record 2 of Set 7 | geraldton
# Processing Record 3 of Set 7 | tawzar
# City not found. Skipping...
# Processing Record 4 of Set 7 | aitape
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | sinazongwe
# Processing Record 7 of Set 7 | auki
# Processing Record 8 of Set 7 | anchorage
# Processing Record 9 of Set 7 | parrita
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | poya
# Processing Record 12 of Set 7 | cairns
# Processing Record 13 of Set 7 | xiongyue
# Processing Record 14 of Set 7 | mikuni
# Processing Record 15 of Set 7 | airai
# Processing Record 16 of Set 7 | colares
# Processing Record 17 of Set 7 | nokaneng
# Processing Record 18 of Set 7 | malartic
# Processing Record 19 of Set 7 | borba
# Processing Record 20 of Set 7 | cabinda
# Processing Record 21 of Set 7 | honiara
# Processing Record 22 of Set 7 | nanortalik
# Processing Record 23 of Set 7 | langres
# Processing Record 24 of Set 7 | ozinki
# Processing Record 25 of Set 7 | chake chake
# Processing Record 26 of Set 7 | iba
# Processing Record 27 of Set 7 | watertown
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | yuci
# Processing Record 30 of Set 7 | kirakira
# Processing Record 31 of Set 7 | kaniama
# Processing Record 32 of Set 7 | saint george
# Processing Record 33 of Set 7 | storforshei
# Processing Record 34 of Set 7 | dingle
# Processing Record 35 of Set 7 | santiago de chuco
# Processing Record 36 of Set 7 | timmins
# Processing Record 37 of Set 7 | uvat
# Processing Record 38 of Set 7 | teberda
# Processing Record 39 of Set 7 | deputatskiy
# Processing Record 40 of Set 7 | manzhouli
# Processing Record 41 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 7 | zaysan
# Processing Record 43 of Set 7 | san ramon de la nueva oran
# Processing Record 44 of Set 7 | mandalgovi
# Processing Record 45 of Set 7 | kabalo
# Processing Record 46 of Set 7 | afonso bezerra
# Processing Record 47 of Set 7 | heiligenhafen
# Processing Record 48 of Set 7 | iquitos
# Processing Record 49 of Set 7 | awbari
# Processing Record 0 of Set 8 | timbiqui
# Processing Record 1 of Set 8 | inirida
# Processing Record 2 of Set 8 | yamethin
# Processing Record 3 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 4 of Set 8 | mahebourg
# Processing Record 5 of Set 8 | urtaaul
# City not found. Skipping...
# Processing Record 6 of Set 8 | stuttgart
# Processing Record 7 of Set 8 | carlsbad
# Processing Record 8 of Set 8 | vardo
# Processing Record 9 of Set 8 | axixa do tocantins
# City not found. Skipping...
# Processing Record 10 of Set 8 | vila
# Processing Record 11 of Set 8 | pevek
# Processing Record 12 of Set 8 | katikati
# Processing Record 13 of Set 8 | kendari
# Processing Record 14 of Set 8 | igarka
# Processing Record 15 of Set 8 | luanda
# Processing Record 16 of Set 8 | sao filipe
# Processing Record 17 of Set 8 | dwarka
# Processing Record 18 of Set 8 | polunochnoye
# Processing Record 19 of Set 8 | vesyegonsk
# Processing Record 20 of Set 8 | tessalit
# Processing Record 21 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 8 | uyuni
# Processing Record 23 of Set 8 | coffs harbour
# Processing Record 24 of Set 8 | padang
# Processing Record 25 of Set 8 | taoudenni
# Processing Record 26 of Set 8 | flinders
# Processing Record 27 of Set 8 | ratanpur
# Processing Record 28 of Set 8 | saint-pierre
# Processing Record 29 of Set 8 | saravan
# Processing Record 30 of Set 8 | yatou
# Processing Record 31 of Set 8 | aljezur
# Processing Record 32 of Set 8 | meulaboh
# Processing Record 33 of Set 8 | ust-tsilma
# Processing Record 34 of Set 8 | yeppoon
# Processing Record 35 of Set 8 | fengrun
# Processing Record 36 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 8 | cabo rojo
# Processing Record 38 of Set 8 | mackay
# Processing Record 39 of Set 8 | henties bay
# Processing Record 40 of Set 8 | plettenberg bay
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | fort nelson
# Processing Record 43 of Set 8 | ushtobe
# Processing Record 44 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 46 of Set 8 | belozerskoye
# Processing Record 47 of Set 8 | uyskoye
# Processing Record 48 of Set 8 | gat
# Processing Record 49 of Set 8 | okha
# Processing Record 0 of Set 9 | namibe
# Processing Record 1 of Set 9 | harpalpur
# Processing Record 2 of Set 9 | tiksi
# Processing Record 3 of Set 9 | yarmouth
# Processing Record 4 of Set 9 | belmonte
# Processing Record 5 of Set 9 | lasa
# Processing Record 6 of Set 9 | kidal
# Processing Record 7 of Set 9 | makakilo city
# Processing Record 8 of Set 9 | talnakh
# Processing Record 9 of Set 9 | gizo
# Processing Record 10 of Set 9 | qaqortoq
# Processing Record 11 of Set 9 | shakhtinsk
# Processing Record 12 of Set 9 | emerald
# Processing Record 13 of Set 9 | bac can
# City not found. Skipping...
# Processing Record 14 of Set 9 | margate
# Processing Record 15 of Set 9 | port hawkesbury
# Processing Record 16 of Set 9 | barabash
# Processing Record 17 of Set 9 | barillas
# Processing Record 18 of Set 9 | bria
# Processing Record 19 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 9 | camacha
# Processing Record 21 of Set 9 | dire dawa
# Processing Record 22 of Set 9 | chifeng
# Processing Record 23 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 9 | tutin
# Processing Record 25 of Set 9 | matamoros
# Processing Record 26 of Set 9 | moba
# Processing Record 27 of Set 9 | katsuura
# Processing Record 28 of Set 9 | el dorado
# Processing Record 29 of Set 9 | goundam
# Processing Record 30 of Set 9 | ahipara
# Processing Record 31 of Set 9 | necochea
# Processing Record 32 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 33 of Set 9 | chokurdakh
# Processing Record 34 of Set 9 | matara
# Processing Record 35 of Set 9 | peterhead
# Processing Record 36 of Set 9 | lerwick
# Processing Record 37 of Set 9 | pangnirtung
# Processing Record 38 of Set 9 | kahului
# Processing Record 39 of Set 9 | pokrovka
# Processing Record 40 of Set 9 | turayf
# Processing Record 41 of Set 9 | coquimbo
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | ndjole
# Processing Record 44 of Set 9 | pisco
# Processing Record 45 of Set 9 | batagay
# Processing Record 46 of Set 9 | ponta delgada
# Processing Record 47 of Set 9 | itarema
# Processing Record 48 of Set 9 | richards bay
# Processing Record 49 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 0 of Set 10 | boyolangu
# Processing Record 1 of Set 10 | khani
# Processing Record 2 of Set 10 | kisangani
# Processing Record 3 of Set 10 | garowe
# Processing Record 4 of Set 10 | iranshahr
# Processing Record 5 of Set 10 | vedaranniyam
# City not found. Skipping...
# Processing Record 6 of Set 10 | hailar
# Processing Record 7 of Set 10 | rezina
# Processing Record 8 of Set 10 | egvekinot
# Processing Record 9 of Set 10 | eureka
# Processing Record 10 of Set 10 | bastrop
# Processing Record 11 of Set 10 | ilirska bistrica
# Processing Record 12 of Set 10 | tongliao
# Processing Record 13 of Set 10 | saurimo
# Processing Record 14 of Set 10 | digha
# Processing Record 15 of Set 10 | ancud
# Processing Record 16 of Set 10 | juba
# Processing Record 17 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 10 | chengdu
# Processing Record 19 of Set 10 | wladyslawowo
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | severo-kurilsk
# Processing Record 22 of Set 10 | coihaique
# Processing Record 23 of Set 10 | akyab
# Processing Record 24 of Set 10 | acapulco
# Processing Record 25 of Set 10 | tara
# Processing Record 26 of Set 10 | kropotkin
# Processing Record 27 of Set 10 | mufulira
# Processing Record 28 of Set 10 | provideniya
# Processing Record 29 of Set 10 | hay river
# Processing Record 30 of Set 10 | miro khan
# Processing Record 31 of Set 10 | suoyarvi
# Processing Record 32 of Set 10 | valley city
# Processing Record 33 of Set 10 | muros
# Processing Record 34 of Set 10 | ha giang
# Processing Record 35 of Set 10 | salta
# Processing Record 36 of Set 10 | armidale
# Processing Record 37 of Set 10 | saldanha
# Processing Record 38 of Set 10 | corrente
# Processing Record 39 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 40 of Set 10 | oyama
# Processing Record 41 of Set 10 | caarapo
# Processing Record 42 of Set 10 | stykkisholmur
# Processing Record 43 of Set 10 | cayenne
# Processing Record 44 of Set 10 | cidreira
# Processing Record 45 of Set 10 | tomatlan
# Processing Record 46 of Set 10 | ust-kuyga
# Processing Record 47 of Set 10 | kavaratti
# Processing Record 48 of Set 10 | barra
# Processing Record 49 of Set 10 | iwanai
# Processing Record 0 of Set 11 | zyryanka
# Processing Record 1 of Set 11 | redcliffe
# Processing Record 2 of Set 11 | mlowo
# Processing Record 3 of Set 11 | a coruna
# Processing Record 4 of Set 11 | puerto escondido
# Processing Record 5 of Set 11 | gushikawa
# Processing Record 6 of Set 11 | maryborough
# Processing Record 7 of Set 11 | bilma
# Processing Record 8 of Set 11 | marquard
# Processing Record 9 of Set 11 | kumeny
# Processing Record 10 of Set 11 | broome
# Processing Record 11 of Set 11 | progreso
# Processing Record 12 of Set 11 | sechura
# Processing Record 13 of Set 11 | marawi
# Processing Record 14 of Set 11 | tanout
# Processing Record 15 of Set 11 | chinsali
# Processing Record 16 of Set 11 | puerto ayacucho
# Processing Record 17 of Set 11 | bara
# Processing Record 18 of Set 11 | carutapera
# Processing Record 19 of Set 11 | kayerkan
# Processing Record 20 of Set 11 | rio verde de mato grosso
# Processing Record 21 of Set 11 | shahi
# Processing Record 22 of Set 11 | waddan
# Processing Record 23 of Set 11 | novyy urgal
# Processing Record 24 of Set 11 | sobolevo
# Processing Record 25 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 11 | wiang sa
# Processing Record 27 of Set 11 | norman wells
# Processing Record 28 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 11 | lompoc
# Processing Record 30 of Set 11 | kota bahru
# Processing Record 31 of Set 11 | gorontalo
# Processing Record 32 of Set 11 | cap malheureux
# Processing Record 33 of Set 11 | sept-iles
# Processing Record 34 of Set 11 | tarakan
# Processing Record 35 of Set 11 | burica
# City not found. Skipping...
# Processing Record 36 of Set 11 | kazerun
# Processing Record 37 of Set 11 | ranfurly
# Processing Record 38 of Set 11 | aykhal
# Processing Record 39 of Set 11 | anito
# Processing Record 40 of Set 11 | vanavara
# Processing Record 41 of Set 11 | devils lake
# Processing Record 42 of Set 11 | berberati
# Processing Record 43 of Set 11 | san borja
# Processing Record 44 of Set 11 | staryy nadym
# Processing Record 45 of Set 11 | stilfontein
# Processing Record 46 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 47 of Set 11 | catuday
# Processing Record 48 of Set 11 | namsos
# Processing Record 49 of Set 11 | fershampenuaz
# Processing Record 0 of Set 12 | diffa
# Processing Record 1 of Set 12 | kudahuvadhoo
# Processing Record 2 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 12 | atikokan
# Processing Record 4 of Set 12 | rawson
# Processing Record 5 of Set 12 | miri
# Processing Record 6 of Set 12 | tucuma
# Processing Record 7 of Set 12 | yining
# Processing Record 8 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 12 | shawinigan
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | sola
# Processing Record 12 of Set 12 | saint-georges
# Processing Record 13 of Set 12 | houma
# Processing Record 14 of Set 12 | tyup
# Processing Record 15 of Set 12 | rondonopolis
# Processing Record 16 of Set 12 | tocopilla
# Processing Record 17 of Set 12 | kohtla-jarve
# Processing Record 18 of Set 12 | warmbad
# Processing Record 19 of Set 12 | methoni
# Processing Record 20 of Set 12 | tura
# Processing Record 21 of Set 12 | levin
# Processing Record 22 of Set 12 | dalnegorsk
# Processing Record 23 of Set 12 | bomi
# Processing Record 24 of Set 12 | torbat-e jam
# Processing Record 25 of Set 12 | lumphat
# Processing Record 26 of Set 12 | morant bay
# Processing Record 27 of Set 12 | ahtopol
# Processing Record 28 of Set 12 | shingu
# Processing Record 29 of Set 12 | sao miguel do araguaia
# Processing Record 30 of Set 12 | esperance
# Processing Record 31 of Set 12 | calamar
# Processing Record 32 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 33 of Set 12 | jizan
# Processing Record 34 of Set 12 | conceicao do araguaia
# Processing Record 35 of Set 12 | horasan
# Processing Record 36 of Set 12 | gloversville
# Processing Record 37 of Set 12 | simplicio mendes
# Processing Record 38 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 12 | salamiyah
# Processing Record 40 of Set 12 | khomeyn
# Processing Record 41 of Set 12 | saint anthony
# Processing Record 42 of Set 12 | flin flon
# Processing Record 43 of Set 12 | segou
# Processing Record 44 of Set 12 | port hardy
# Processing Record 45 of Set 12 | san cristobal
# Processing Record 46 of Set 12 | oktyabrskoye
# Processing Record 47 of Set 12 | makokou
# Processing Record 48 of Set 12 | oriximina
# Processing Record 49 of Set 12 | carballo
# Processing Record 0 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 13 | winneba
# Processing Record 2 of Set 13 | huarmey
# Processing Record 3 of Set 13 | teya
# Processing Record 4 of Set 13 | montepuez
# Processing Record 5 of Set 13 | tarko-sale
# Processing Record 6 of Set 13 | xuanhua
# Processing Record 7 of Set 13 | tabou
# Processing Record 8 of Set 13 | katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_info ['clouds']['all'])
# Out:
# 100

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          555
# Lat           555
# Lng           555
# Max Temp      555
# Humidity      555
# Cloudiness    555
# Wind Speed    555
# Country       555
# Date          555
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       rikitea -23.1203 -134.9692     23.18        73          18
# 1      lorengau  -2.0226  147.2712     27.39        78         100
# 2      kalmunai   7.4167   81.8167     25.70        84          96
# 3  punta arenas -53.1500  -70.9167     10.06        50          20
# 4         vaini -21.2000 -175.2000     25.09        88          75
#
#    Wind Speed Country        Date
# 0        6.33      PF  1670086083
# 1        3.27      PG  1670086084
# 2        2.06      LK  1670086084
# 3       12.35      CL  1670086084
# 4        3.09      TO  1670086085

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
dfcities = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
dfcities.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             rikitea -23.1203 -134.9692     23.18        73          18
# 1            lorengau  -2.0226  147.2712     27.39        78         100
# 2            kalmunai   7.4167   81.8167     25.70        84          96
# 3        punta arenas -53.1500  -70.9167     10.06        50          20
# 4               vaini -21.2000 -175.2000     25.09        88          75
#
#          Wind Speed Country        Date
# City_ID
# 0              6.33      PF  1670086083
# 1              3.27      PG  1670086084
# 2              2.06      LK  1670086084
# 3             12.35      CL  1670086084
# 4              3.09      TO  1670086085

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
#city_data_df.plot(kind="scatter", x='Lat', y='Max Temp', grid=True, figsize=(8,8))
ts = time.gmtime(dfcities['Date'][0])
datestr = time.strftime("%x",ts)
plt.scatter(dfcities['Lat'],dfcities['Max Temp'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f"City Max Latitude vs. Temperature({datestr})")
plt.xlabel('Latitude',fontsize =14)
plt.ylabel('Max Temperature (C)',fontsize =14)
# Incorporate the other graph properties

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
#city_data_df.plot(kind="scatter", x='Lat', y='Humidity', grid=True, figsize=(8,8))

ts = time.gmtime(dfcities['Date'][0])
datestr = time.strftime("%x",ts)
plt.scatter(dfcities['Lat'],dfcities['Humidity'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f'City Latitude vs. Humidity({datestr})')
plt.xlabel('Latitude',fontsize =14)
plt.ylabel('Humidity(%)',fontsize =14)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
ts = time.gmtime(dfcities['Date'][0])
datestr = time.strftime("%x",ts)
plt.scatter(dfcities['Lat'],dfcities['Cloudiness'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f'City Latitude vs. Cloudiness({datestr})')
plt.xlabel('Latitude',fontsize =14)
plt.ylabel('Cloudiness(%)',fontsize =14)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
ts = time.gmtime(dfcities['Date'][0])
datestr = time.strftime("%x",ts)
plt.scatter(dfcities['Lat'],dfcities['Wind Speed'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f'City Latitude vs. Cloudiness({datestr})')
plt.xlabel('Latitude',fontsize =14)
plt.ylabel('Wind Speed(m/s)',fontsize =14)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig(f"../output_data/fig{ifig}.png")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
nothern =[]
nothern =dfcities.loc [dfcities["Lat"] >= 0.0]
#nothern.reset_index(inplace=True)

# Display sample data
nothern
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2          kalmunai   7.4167   81.8167     25.70        84          96
# 5            gwadar  25.1216   62.3254     24.49        36           0
# 10         atakpame   7.5333    1.1333     30.37        45          63
# 15         portland  45.5234 -122.6762      3.68        63          40
# 16          zuwarah  32.9312   12.0820     20.62        40           3
# ...             ...      ...       ...       ...       ...         ...
# 547         winneba   5.3511   -0.6231     27.22        78          80
# 549            teya  60.3778   92.6267    -20.38        98          99
# 551      tarko-sale  64.9225   77.7850    -11.77        96          93
# 552         xuanhua  40.6103  115.0447     -9.96        30           0
# 553           tabou   4.4230   -7.3528     26.22        82          95
#
#          Wind Speed Country        Date
# City_ID
# 2              2.06      LK  1670086084
# 5              3.64      PK  1670086085
# 10             2.60      TG  1670086086
# 15             6.71      US  1670085798
# 16             1.02      LY  1670086088
# ...             ...     ...         ...
# 547            5.09      GH  1670086267
# 549            1.78      RU  1670086268
# 551            4.49      RU  1670086268
# 552            2.14      CN  1670086269
# 553            3.56      CI  1670086269
#
# [381 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern=[]
southern = dfcities.loc[dfcities["Lat"] < 0.0]
#southern.reset_index(inplace=True)
# Display sample data
southern
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 rikitea -23.1203 -134.9692     23.18        73          18
# 1                lorengau  -2.0226  147.2712     27.39        78         100
# 3            punta arenas -53.1500  -70.9167     10.06        50          20
# 4                   vaini -21.2000 -175.2000     25.09        88          75
# 6                  hobart -42.8794  147.3294     13.92        94         100
# ...                   ...      ...       ...       ...       ...         ...
# 535      simplicio mendes  -7.8539  -41.9103     34.23        29          77
# 545             oriximina  -1.7656  -55.8661     32.31        52          66
# 548               huarmey -10.0681  -78.1522     22.25        74          11
# 550             montepuez -13.1256   38.9997     27.26        47          95
# 554             katherine -14.4667  132.2667     25.18        61         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.33      PF  1670086083
# 1              3.27      PG  1670086084
# 3             12.35      CL  1670086084
# 4              3.09      TO  1670086085
# 6              0.00      AU  1670085903
# ...             ...     ...         ...
# 535            3.60      BR  1670086262
# 545            2.04      BR  1670086266
# 548            4.25      PE  1670086267
# 550            3.53      MZ  1670086268
# 554            1.54      AU  1670086269
#
# [174 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (30,30)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.8478932311140885

# %%
# Linear regression on Southern Hemisphere
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (-55,35)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,6)
# Out:
# The r-squared is: 0.6415662043517734

# %%
Temperature vs. Latitude Linear Regression
# Linear regression on Northern Hemisphere is negative correlation.
# Linear regression on Southern Hemisphere is positive correlation
the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). 
More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the
northern hemisphere. This may be due to the tilt of the earth.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (40,20)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: 0.3554295611875113

# %%
# Southern Hemisphere
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (-50,90)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,8)
# Out:
# The r-squared is: 0.14194576846305298

# %%
Humidity vs. Latitude Linear Regression
# Northern Hemisphere is no correlation
# Southern Hemisphere is no correlation
From this randomized data set, we can infer that there is little to no correlation between humidity and 
the location's latitude.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (40,60)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,9)
# Out:
# The r-squared is: 0.1456429775748801

# %%
# Southern Hemisphere
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-55,50)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.283302809310522

# %%
#Cloudiness vs. Latitude Linear Regression Plot
Northern Hemisphere and Southern Hemisphere have positive correlation but r-squre is >0.3 .
There is no strong relationship between latitude and cloudiness. 
However, it is interesting to see that a strong band of cities sits at 0, 80 cloudiness
Nor does their appear to be any correlation between cloud coverage and the location's latitude.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
mxlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (40,15)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,11)
# Out:
# The r-squared is: 0.29635568338633456

# %%
# Southern Hemisphere
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (-30,12)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,12)
# Out:
# The r-squared is: -0.3469177905747826

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#Wind Speed vs. Latitude Linear Regression 
# Northern Hemisphere have positive correlation and  Southern Hemisphere have negative correlation

No significant correlation was found between latitude and  wind speed. Frequency of wind speed, however, 
can be observed. Especially, for wind speeds between 0-10 mph
